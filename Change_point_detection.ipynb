# %% [markdown]
# #### Импорт библиотек

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import sys

# %%
# !pip install changefinder
# Out:
# Requirement already satisfied: changefinder in c:\users\pc\anaconda3\lib\site-packages (0.3)
# Requirement already satisfied: scipy in c:\users\pc\anaconda3\lib\site-packages (from changefinder) (1.7.3)
# Requirement already satisfied: statsmodels in c:\users\pc\anaconda3\lib\site-packages (from changefinder) (0.12.2)
# Requirement already satisfied: numpy in c:\users\pc\anaconda3\lib\site-packages (from changefinder) (1.21.5)
# Requirement already satisfied: nose in c:\users\pc\anaconda3\lib\site-packages (from changefinder) (1.3.7)
# Requirement already satisfied: patsy>=0.5 in c:\users\pc\anaconda3\lib\site-packages (from statsmodels->changefinder) (0.5.2)
# Requirement already satisfied: pandas>=0.21 in c:\users\pc\anaconda3\lib\site-packages (from statsmodels->changefinder) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\pc\anaconda3\lib\site-packages (from pandas>=0.21->statsmodels->changefinder) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pc\anaconda3\lib\site-packages (from pandas>=0.21->statsmodels->changefinder) (2021.3)
# Requirement already satisfied: six in c:\users\pc\anaconda3\lib\site-packages (from patsy>=0.5->statsmodels->changefinder) (1.16.0)

# %%
import changefinder
# Out:
# C:\Users\PC\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# C:\Users\PC\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %% [markdown]
# ### Сначала рассмотрим результат действия методов на синтетических данных

# %% [markdown]
# Генерация данных

# %%
# Постоянная дисперсия
ts1 = []
mu, sigma, seg = 0.0, 1.0, 1000
for i in range(10):
    ts = np.random.normal(mu, sigma, seg) + np.random.randint(low=-10, high=10)
    ts1 = np.append(ts1,ts, axis=0)
plt.figure(figsize=(16,4))
plt.title('Example 1: constant variance')
plt.plot(ts1)

# %%
# Изменяющаяся дисперсия
ts2 = []
mu, sigma, seg = 0.0, 1.0, 1000
for i in range(10):
    sig = np.random.randint(low=1, high=50)
    ts = np.random.normal(mu, sigma * sig, seg) 
    ts2 = np.append(ts2,ts, axis=0)    
plt.figure(figsize=(16,4))
plt.title('Example 2: varying variance')
plt.plot(ts2)

# %% [markdown]
# ###  Changefinder (online)

# %%
def findChangePoints(ts, r, order, smooth):
    '''
       r: Discounting rate
       order: AR model order
       smooth: smoothing window size T
    '''
    cf = changefinder.ChangeFinder(r=r, order=order, smooth=smooth)
    ts_score = [cf.update(p) for p in ts]
    plt.figure(figsize=(16,4))
    plt.plot(ts)
    plt.figure(figsize=(16,4))
    plt.plot(ts_score, color='red')
    return(ts_score)

# %% [markdown]
# #### Случай с постоянной дисперсией

# %% [markdown]
# Получаем точки изменения

# %%
ts_score1 = findChangePoints(ts1, r = 0.01, order = 3, smooth = 5)

# %% [markdown]
# Вывод точек изменения

# %%
ts_change_loc1 = pd.Series(ts_score1).nlargest(30)
ts_change_loc1 = ts_change_loc1.index
ts_change_loc1
# Out:
# Int64Index([ 661, 2001,   11,  662, 7001,  660, 2008, 2007, 9008, 7000, 2000,
#             7008, 9007, 7007, 6008, 3008, 6007, 3009, 6001,   15, 9601,  659,
#             8008, 2002, 9600, 6002, 7004, 9001, 8583, 8582],
#            dtype='int64')

# %% [markdown]
# Визуализация полученных данных

# %%
def plot_change_points(ts,ts_change_loc):
    plt.figure(figsize=(16,4))
    plt.plot(ts)
    for x in ts_change_loc:
        plt.axvline(x,lw=2, color='red')

# %%
plot_change_points(ts1,ts_change_loc1)

# %% [markdown]
# #### Случай с изменяющейся дисперсией

# %%
ts_score2 = findChangePoints(ts2, r = 0.01,     order = 3,  smooth =3)

# %% [markdown]
# Получение точек изменения

# %%
ts_change_loc2 = pd.Series(ts_score2).nlargest(30)
ts_change_loc2 = ts_change_loc2.index
ts_change_loc2
# Out:
# Int64Index([  26,    9,   25,   12,   11, 3011,   27, 3007, 3012, 3006,   21,
#               10,   22, 2312, 2311, 3004, 1959, 3016, 2315, 8857, 2314, 7832,
#             1960, 7831, 8858, 8212, 6042, 6043, 3003, 3015],
#            dtype='int64')

# %% [markdown]
# Визуализация полученных данных

# %%
plot_change_points(ts2,ts_change_loc2)

# %% [markdown]
# ### Ruptures (offline)

# %% [markdown]
# #### Случай с постоянной дисперсией

# %%
# !pip install ruptures
import ruptures as rpt
# Out:
# Requirement already satisfied: ruptures in c:\users\pc\anaconda3\lib\site-packages (1.1.7)
# Requirement already satisfied: scipy in c:\users\pc\anaconda3\lib\site-packages (from ruptures) (1.7.3)
# Requirement already satisfied: numpy in c:\users\pc\anaconda3\lib\site-packages (from ruptures) (1.21.5)

# %% [markdown]
# Обнаружение точек изменения

# %%
algo1 = rpt.Pelt(model="rbf").fit(ts1)
change_location1 = algo1.predict(pen=10)
change_location1
# Out:
# [2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000]

# %% [markdown]
# Визуализация полученных данных

# %%
plot_change_points(ts1,change_location1)

# %% [markdown]
# #### Случай с изменяющейся дисперсией

# %% [markdown]
# Обнаружение точек изменения

# %%
algo2 = rpt.Pelt(model="rbf").fit(ts2)
change_location2 = algo2.predict(pen=10)
change_location2
# Out:
# [2000, 3005, 5005, 6995, 10000]

# %%
plot_change_points(ts2,change_location2)

# %% [markdown]
# Подход основанный на оффлайн (Raptures) прогнозировании показал лучший результат, рассмотрим данный метод покажет себя на реалных данных.

# %% [markdown]
# ### Рассмотрим на данных SWaT (реальные данные)

# %%
data = pd.read_excel('SWaT_Dataset_Attack_v0 (1).xlsx', skiprows = 1)
data.head(5)
# Out:
# C:\Users\PC\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                  Timestamp    FIT101    LIT101   MV101  P101  P102    AIT201  \
# 0   28/12/2015 10:00:00 AM  2.427057  522.8467       2     2     1  262.0161
# 1   28/12/2015 10:00:01 AM  2.446274  522.8860       2     2     1  262.0161
# 2   28/12/2015 10:00:02 AM  2.489191  522.8467       2     2     1  262.0161
# 3   28/12/2015 10:00:03 AM  2.534350  522.9645       2     2     1  262.0161
# 4   28/12/2015 10:00:04 AM  2.569260  523.4748       2     2     1  262.0161
#
#      AIT202    AIT203    FIT201  ...  P501  P502    PIT501    PIT502  \
# 0  8.396437  328.6337  2.445391  ...     2     1  250.8652  1.649953
# 1  8.396437  328.6337  2.445391  ...     2     1  250.8652  1.649953
# 2  8.394514  328.6337  2.442316  ...     2     1  250.8812  1.649953
# 3  8.394514  328.6337  2.442316  ...     2     1  250.8812  1.649953
# 4  8.394514  328.6337  2.443085  ...     2     1  250.8812  1.649953
#
#      PIT503    FIT601  P601  P602  P603  Normal/Attack
# 0  189.5988  0.000128     1     1     1         Normal
# 1  189.6789  0.000128     1     1     1         Normal
# 2  189.6789  0.000128     1     1     1         Normal
# 3  189.6148  0.000128     1     1     1         Normal
# 4  189.5027  0.000128     1     1     1         Normal
#
# [5 rows x 53 columns]

# %% [markdown]
# Переведем колонку Timestamp в формат времени

# %%
data[' Timestamp'] = pd.to_datetime(data[' Timestamp'])

# %%
data[' Timestamp']
# Out:
# 0        2015-12-28 10:00:00
# 1        2015-12-28 10:00:01
# 2        2015-12-28 10:00:02
# 3        2015-12-28 10:00:03
# 4        2015-12-28 10:00:04
#                  ...
# 449914   2016-02-01 14:59:55
# 449915   2016-02-01 14:59:56
# 449916   2016-02-01 14:59:57
# 449917   2016-02-01 14:59:58
# 449918   2016-02-01 14:59:59
# Name:  Timestamp, Length: 449919, dtype: datetime64[ns]

# %% [markdown]
# Установим колонку Timestamp индексом

# %%
data = data.set_index(' Timestamp')

# %%
data.head(3)
# Out:
#                        FIT101    LIT101   MV101  P101  P102    AIT201  \
#  Timestamp
# 2015-12-28 10:00:00  2.427057  522.8467       2     2     1  262.0161
# 2015-12-28 10:00:01  2.446274  522.8860       2     2     1  262.0161
# 2015-12-28 10:00:02  2.489191  522.8467       2     2     1  262.0161
#
#                        AIT202    AIT203    FIT201   MV201  ...  P501  P502  \
#  Timestamp                                                 ...
# 2015-12-28 10:00:00  8.396437  328.6337  2.445391       2  ...     2     1
# 2015-12-28 10:00:01  8.396437  328.6337  2.445391       2  ...     2     1
# 2015-12-28 10:00:02  8.394514  328.6337  2.442316       2  ...     2     1
#
#                        PIT501    PIT502    PIT503    FIT601  P601  P602  P603  \
#  Timestamp
# 2015-12-28 10:00:00  250.8652  1.649953  189.5988  0.000128     1     1     1
# 2015-12-28 10:00:01  250.8652  1.649953  189.6789  0.000128     1     1     1
# 2015-12-28 10:00:02  250.8812  1.649953  189.6789  0.000128     1     1     1
#
#                      Normal/Attack
#  Timestamp
# 2015-12-28 10:00:00         Normal
# 2015-12-28 10:00:01         Normal
# 2015-12-28 10:00:02         Normal
#
# [3 rows x 52 columns]

# %% [markdown]
# Рассмотрим, какие признаки есть в данном датасете

# %%
cols = data.columns
cols
# Out:
# Index(['FIT101', 'LIT101', ' MV101', 'P101', 'P102', ' AIT201', 'AIT202',
#        'AIT203', 'FIT201', ' MV201', ' P201', ' P202', 'P203', ' P204', 'P205',
#        'P206', 'DPIT301', 'FIT301', 'LIT301', 'MV301', 'MV302', ' MV303',
#        'MV304', 'P301', 'P302', 'AIT401', 'AIT402', 'FIT401', 'LIT401', 'P401',
#        'P402', 'P403', 'P404', 'UV401', 'AIT501', 'AIT502', 'AIT503', 'AIT504',
#        'FIT501', 'FIT502', 'FIT503', 'FIT504', 'P501', 'P502', 'PIT501',
#        'PIT502', 'PIT503', 'FIT601', 'P601', 'P602', 'P603', 'Normal/Attack'],
#       dtype='object')

# %% [markdown]
# Возьмем только первые 5000 значений

# %%
df = data[:5000]
df
# Out:
#                        FIT101    LIT101   MV101  P101  P102    AIT201  \
#  Timestamp
# 2015-12-28 10:00:00  2.427057  522.8467       2     2     1  262.0161
# 2015-12-28 10:00:01  2.446274  522.8860       2     2     1  262.0161
# 2015-12-28 10:00:02  2.489191  522.8467       2     2     1  262.0161
# 2015-12-28 10:00:03  2.534350  522.9645       2     2     1  262.0161
# 2015-12-28 10:00:04  2.569260  523.4748       2     2     1  262.0161
# ...                       ...       ...     ...   ...   ...       ...
# 2015-12-28 11:23:15  2.617301  662.0323       2     1     1  263.3299
# 2015-12-28 11:23:16  2.605771  663.0323       2     1     1  263.3299
# 2015-12-28 11:23:17  2.594562  664.0323       2     1     1  263.3299
# 2015-12-28 11:23:18  2.574384  665.0323       2     1     1  263.3299
# 2015-12-28 11:23:19  2.550043  666.0323       2     1     1  263.3299
#
#                        AIT202    AIT203    FIT201   MV201  ...  P501  P502  \
#  Timestamp                                                 ...
# 2015-12-28 10:00:00  8.396437  328.6337  2.445391       2  ...     2     1
# 2015-12-28 10:00:01  8.396437  328.6337  2.445391       2  ...     2     1
# 2015-12-28 10:00:02  8.394514  328.6337  2.442316       2  ...     2     1
# 2015-12-28 10:00:03  8.394514  328.6337  2.442316       2  ...     2     1
# 2015-12-28 10:00:04  8.394514  328.6337  2.443085       2  ...     2     1
# ...                       ...       ...       ...     ...  ...   ...   ...
# 2015-12-28 11:23:15  8.447386  317.0982  0.000000       1  ...     2     1
# 2015-12-28 11:23:16  8.447386  317.0982  0.000000       1  ...     2     1
# 2015-12-28 11:23:17  8.447386  317.0982  0.000000       1  ...     2     1
# 2015-12-28 11:23:18  8.447386  317.0982  0.000000       1  ...     2     1
# 2015-12-28 11:23:19  8.447386  317.0982  0.000000       1  ...     2     1
#
#                        PIT501    PIT502    PIT503    FIT601  P601  P602  P603  \
#  Timestamp
# 2015-12-28 10:00:00  250.8652  1.649953  189.5988  0.000128     1     1     1
# 2015-12-28 10:00:01  250.8652  1.649953  189.6789  0.000128     1     1     1
# 2015-12-28 10:00:02  250.8812  1.649953  189.6789  0.000128     1     1     1
# 2015-12-28 10:00:03  250.8812  1.649953  189.6148  0.000128     1     1     1
# 2015-12-28 10:00:04  250.8812  1.649953  189.5027  0.000128     1     1     1
# ...                       ...       ...       ...       ...   ...   ...   ...
# 2015-12-28 11:23:15  249.9840  1.762086  188.7977  0.000256     1     1     1
# 2015-12-28 11:23:16  249.9840  1.762086  188.7977  0.000256     1     1     1
# 2015-12-28 11:23:17  249.9840  1.762086  188.8618  0.000256     1     1     1
# 2015-12-28 11:23:18  249.9840  1.762086  188.8779  0.000256     1     1     1
# 2015-12-28 11:23:19  250.1762  1.762086  188.9580  0.000256     1     1     1
#
#                      Normal/Attack
#  Timestamp
# 2015-12-28 10:00:00         Normal
# 2015-12-28 10:00:01         Normal
# 2015-12-28 10:00:02         Normal
# 2015-12-28 10:00:03         Normal
# 2015-12-28 10:00:04         Normal
# ...                            ...
# 2015-12-28 11:23:15         Attack
# 2015-12-28 11:23:16         Attack
# 2015-12-28 11:23:17         Attack
# 2015-12-28 11:23:18         Attack
# 2015-12-28 11:23:19         Attack
#
# [5000 rows x 52 columns]

# %% [markdown]
# #### Преобразуем данные в необходимый вид
# В метод fit, необходимо подать сигнал следующей размерности: (n_samples, n_features)

# %%
df = df.drop(columns=["Normal/Attack"], axis=1)

# %%
list1=[]
for i in df.columns:
    list1.append(i)

# %%
list2=[]
for i in list1:
    list2.append(df[i].values)

# %%
arr1 = np.vstack(list2).T
print(np.shape(arr1))
# Out:
# (5000, 51)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
arr = scaler.fit_transform(arr)

# %% [markdown]
# Обучение

# %%
result = rpt.Pelt(model="rbf").fit(arr)
change_location1 = result.predict(pen=10)

# %% [markdown]
# Обнаруженные точки изменения

# %%
change_location1
# Out:
# [305,
#  710,
#  745,
#  800,
#  1045,
#  1330,
#  1370,
#  1740,
#  1835,
#  1870,
#  2210,
#  2675,
#  3045,
#  3140,
#  3195,
#  3245,
#  3285,
#  3420,
#  3490,
#  3900,
#  4350,
#  4680,
#  5000]

# %% [markdown]
# Предсказанные точки изменения

# %%
plot_change_points(arr,change_location1)

# %% [markdown]
# #### Получим предсказанные точки изменения

# %% [markdown]
# Сначала создадим пустой Series

# %%
prediction = pd.Series(0,pd.date_range('2015-12-28 10:00:00','2015-12-28 11:23:19',freq='S'))

# %%
prediction
# Out:
# 2015-12-28 10:00:00    0
# 2015-12-28 10:00:01    0
# 2015-12-28 10:00:02    0
# 2015-12-28 10:00:03    0
# 2015-12-28 10:00:04    0
#                       ..
# 2015-12-28 11:23:15    0
# 2015-12-28 11:23:16    0
# 2015-12-28 11:23:17    0
# 2015-12-28 11:23:18    0
# 2015-12-28 11:23:19    0
# Freq: S, Length: 5000, dtype: int64

# %% [markdown]
# Добавим в него метки точек изменения

# %%
j=0
for j in change_location1:
    prediction.iloc[j-1]=1
prediction
# Out:
# 2015-12-28 10:00:00    0
# 2015-12-28 10:00:01    0
# 2015-12-28 10:00:02    0
# 2015-12-28 10:00:03    0
# 2015-12-28 10:00:04    0
#                       ..
# 2015-12-28 11:23:15    0
# 2015-12-28 11:23:16    0
# 2015-12-28 11:23:17    0
# 2015-12-28 11:23:18    0
# 2015-12-28 11:23:19    1
# Freq: S, Length: 5000, dtype: int64

# %% [markdown]
# Получим реальные точки изменения

# %%
true = data["Normal/Attack"]
true=true[:5000]
true
# Out:
#  Timestamp
# 2015-12-28 10:00:00    Normal
# 2015-12-28 10:00:01    Normal
# 2015-12-28 10:00:02    Normal
# 2015-12-28 10:00:03    Normal
# 2015-12-28 10:00:04    Normal
#                         ...
# 2015-12-28 11:23:15    Attack
# 2015-12-28 11:23:16    Attack
# 2015-12-28 11:23:17    Attack
# 2015-12-28 11:23:18    Attack
# 2015-12-28 11:23:19    Attack
# Name: Normal/Attack, Length: 5000, dtype: object

# %% [markdown]
# Сначала создадим пустой Series

# %%
trues = pd.Series(0,pd.date_range('2015-12-28 10:00:00','2015-12-28 11:23:19',freq='S'))

# %% [markdown]
# Возьмем только первые аномалии и будем считать, что они являются точками изменения

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
j=0
while j in range(len(true)):
    num = j + 1
    if true[j] == "Attack":
        trues.iloc[j]=1
        # остальным еденицам присваиваем 0
        if true[num] == "Attack":
            while true[num] == "Attack" and num < (len(true)-1):
                trues.iloc[num] == 0
                num +=1
                j = num
    j = j+1
           
trues
# Out:
# 2015-12-28 10:00:00    0
# 2015-12-28 10:00:01    0
# 2015-12-28 10:00:02    0
# 2015-12-28 10:00:03    0
# 2015-12-28 10:00:04    0
#                       ..
# 2015-12-28 11:23:15    0
# 2015-12-28 11:23:16    0
# 2015-12-28 11:23:17    0
# 2015-12-28 11:23:18    0
# 2015-12-28 11:23:19    0
# Freq: S, Length: 5000, dtype: int64

# %% [markdown]
# Объединим предсказанные и реальные значения в один датафрейм

# %%
df = pd.concat([trues,prediction],1, keys=["true", "pred"]).reset_index()
df
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_2036\480551942.py:1: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   df = pd.concat([trues,prediction],1, keys=["true", "pred"]).reset_index()
#                    index  true  pred
# 0    2015-12-28 10:00:00     0     0
# 1    2015-12-28 10:00:01     0     0
# 2    2015-12-28 10:00:02     0     0
# 3    2015-12-28 10:00:03     0     0
# 4    2015-12-28 10:00:04     0     0
# ...                  ...   ...   ...
# 4995 2015-12-28 11:23:15     0     0
# 4996 2015-12-28 11:23:16     0     0
# 4997 2015-12-28 11:23:17     0     0
# 4998 2015-12-28 11:23:18     0     0
# 4999 2015-12-28 11:23:19     0     1
#
# [5000 rows x 3 columns]

# %% [markdown]
# Переименуем для удобства столбец index в time

# %%
df.rename(columns={'index': 'time'}, inplace=True)

# %%
# реальные точки изменения
df[df["true"] == 1]
# Out:
#                     time  true  pred
# 1754 2015-12-28 10:29:14     1     0
# 3068 2015-12-28 10:51:08     1     0
# 4920 2015-12-28 11:22:00     1     0

# %% [markdown]
# #### Оценим полученный результат

# %% [markdown]
# Метрики

# %% [markdown]
# MAE

# %%
import datetime as dt
today = dt.date.today()

def maerror(df):
    # Получаем оценку насколько в среднем предсказанная точка изменения (аномалия) близка к действительной
    time_true = 0
    time_pred = 0
    
    for i in range(len(df["true"])-1):

        if df['true'][i] == 1 and df["pred"][i] != 1:
            time_true = dt.datetime.strptime(str(df["time"][i]), '%Y-%m-%d %H:%M:%S').time()
            num = i
            while df["pred"][num] != 1:
                num +=1
                if df["pred"][num] == 1:
                    time_pred = dt.datetime.strptime(str(df["time"][num]), '%Y-%m-%d %H:%M:%S').time()
    
        if df['true'][i] != 1 and df["pred"][i] == 1:
            time_pred = dt.datetime.strptime(str(df["time"][i]), '%Y-%m-%d %H:%M:%S').time()
            num = i
            while df["true"][num] != 1:
                num +=1
                if df["true"][num] == 1:
                    time_true = dt.datetime.strptime(str(df["time"][num]), '%Y-%m-%d %H:%M:%S').time()
                             
        if df['true'][i] == 1 and df["pred"][i] == 1:     
            time_true = dt.datetime.strptime(str(df["time"][i]), '%Y-%m-%d %H:%M:%S').time() 
            time_pred = dt.datetime.strptime(str(df["time"][i]), '%Y-%m-%d %H:%M:%S').time()
                          
        if time_true != 0 and time_pred != 0:        
        #находим разницу между реальным и предсказанным значением
            if time_true > time_pred:
                duration = -1*(dt.datetime.combine(today, time_pred) - dt.datetime.combine(today, time_true))
            else: 
                duration = dt.datetime.combine(today, time_pred) - dt.datetime.combine(today, time_true)
            # рассчитываем MAE (нормируем по числу аномальных точек)
            mae = np.sum(duration)/(len(df[df["pred"] == 1])-1)
            
            return print("MAE: {}". format(mae))

# %%
maerror(df)
# Out:
# MAE: 0:01:05.909091

# %% [markdown]
# Рассмотрим следующие метрики: F1 measure, Recall, Precision, Accuracy

# %%
from sklearn.metrics import roc_auc_score
import sklearn.metrics as metrics

# %%
def classif_metrics(df):
    # Рассчитаем TP, FP, FN, TN
    TP, FP, FN, TN = 0, 0, 0, 0
    
    eq = df[df['true'] == df['pred']]

    TP = eq[eq['true'] == 1].shape[0]
    TN = eq[eq['true'] == 0].shape[0]

    not_eq = df[df['true'] != df['pred']]

    FP = not_eq[not_eq['true'] == 0].shape[0]
    FN = not_eq[not_eq['true'] == 1].shape[0]

    print('True Positives:%.0f'%(TP), end = '\t')
    print('False Positives:%.0f'%(FP))
    print('False Negatives:%.0f'%(FN), end = '\t')
    print('True Negatives:%.0f'%(TN))
    
    # Рассчитаем: Accuracy, Recall, Precission, F1 measure
    print('Accuracy:%.4f'% ((TP + TN) / (TP+TN+FP+FN)))
    print('Recall:%.4f'% (TP / (TP + FN)), end = '\t')
    print('Precision:%.4f'%(TP / (TP + FP)))
    print('f1 measure:%.4f'%(TP / (TP + 0.5*(FP+FN))))
    return TP,TN,FP,FN

# %%
classif_metrics(df)
# Out:
# True Positives:0	False Positives:23
# False Negatives:3	True Negatives:4974
# Accuracy:0.9948
# Recall:0.0000	Precision:0.0000
# f1 measure:0.0000
# (0, 4974, 23, 3)

# %% [markdown]
# NAB

# %%
import tsad
from tsad.evaluating.evaluating import evaluating

# %%
df2 = df.copy()

# %%
df2.set_index('time', inplace=True)
df2.head()
# Out:
#                      true  pred
# time
# 2015-12-28 10:00:00     0     0
# 2015-12-28 10:00:01     0     0
# 2015-12-28 10:00:02     0     0
# 2015-12-28 10:00:03     0     0
# 2015-12-28 10:00:04     0     0

# %%
numenta_time = "3min" # размер окна
results = evaluating(true=df2["true"],prediction=df2["pred"], 
                     numenta_time=numenta_time, #Размер окна (10% от всего ряда, деленное на число реальных аномалий)
                     anomaly_window_destenation='center', # Расположение окна относительно аномалии
                     metric='nab', clear_anomalies_mode=True,plot_figure=True) 
# Результат:
# Standart - назначает TPs, FPs и FNs с относительными весами (привязанными к размеру окна)
# случайные обнаружения, сделанные в 10% случаев, получат в среднем нулевую итоговую оценку
# LowFP и LowFN - начисляют большие штрафы за FPs и FNs, предназначены для иллюстрации поведения алгоритма.
# Out:
# Standart  -  36.96
# LowFP  -  0.98
# LowFN  -  57.97

# %% [markdown]
# Красные линии-это реальные точки изменения (аномалии), синие - предсказанные.
# Зеленым цветом показанно окно, в которое попадают предсказанные точки изменения

# %% [markdown]
# Здесь также стоит отметить, что не все точки изменения являются аномалиями, поэтому мы видим такой результат
